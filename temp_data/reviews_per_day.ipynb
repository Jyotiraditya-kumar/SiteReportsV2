# %%
import requests
import pandas as pd
from src import utilities as utils
import random
from retry import retry
from src import config
from pathlib import Path
from src import clogger as logger
import hashlib
import time
import json
from datetime import datetime
import re

# %%
from concurrent.futures import ThreadPoolExecutor

# BASE_DIR = config.PROJECT_DIR / "data" / "zomato"
CACHE_DIR = Path("/media/jyotiraditya/Ultra Touch/Spatic/cache_home/cache_zomato_reviews")
log = logger.get_logger('ZomatoRestaurants')
logging = log


def get_random_proxy(index=None):
    available_proxies = utils.get_other_proxies()
    if len(available_proxies) == 0:
        raise Exception('No proxy available')

    if index is not None and 0 <= index < len(available_proxies):
        index = index % len(available_proxies)
        current_proxy = available_proxies[index]
    else:
        current_proxy_ind = random.choice(range(len(available_proxies)))
        current_proxy = available_proxies[current_proxy_ind]
    proxy = {
        "https": current_proxy
    }
    return proxy


class EmptyPageError(Exception):
    pass

# %%
@retry(exceptions=(EmptyPageError,), tries=3, delay=3)
def get_html_response_google(hex_id, num_reviews, proxy):
    # proxy=get_random_proxy()
    BASE_DIR = config.PROJECT_DIR / "data" / "google"
    CACHE_DIR = Path("/media/jyotiraditya/Ultra Touch/Spatic/cache_home/cache_google_reviews_oldest")
    log = logger.get_logger('GoogleReviews')
    logging = log
    dig = hashlib.md5(f"{hex_id}_{num_reviews}_fetch_latest=true".encode()).hexdigest()
    cache_dirs = [BASE_DIR / 'cache', CACHE_DIR, ]
    lambda_url = random.choice(["https://u7ub4ix7quehlb4mptoucjvndu0brrnf.lambda-url.us-east-2.on.aws",
                                "https://sadxe5vx7h3wdbi3j5z5za3o5a0mxgtk.lambda-url.us-east-1.on.aws"])
    url = f"{lambda_url}/?hex_id={hex_id}&num_reviews={num_reviews}&fetch_latest=true"
    for cache_dir in cache_dirs:
        cache_dir.mkdir(parents=True, exist_ok=True)
        cache_file = cache_dir / f'{dig}.txt'
        if cache_file.exists():
            with open(cache_file) as f:
                resp = f.read()
                if "Expecting value" in resp:
                    print('deleting file')
                    cache_file.unlink()
                    continue
                return resp
    try:
        print("making request")
        response = requests.get(
            url,
            headers=None,
            proxies=None, timeout=10,
        )
        if response.status_code == 200:
            time.sleep(1)
            text = response.text
            if "Expecting value" in text:
                raise EmptyPageError
            with open(cache_file, 'w+') as f:
                f.write(text)
            data = json.loads(text)
            if data['statusCode'] == 200:
                return text
            else:
                log.error(text)
                raise ValueError
        else:
            log.error(response.text, response.status_code)
            raise EmptyPageError
    except Exception as e:
        log.error(f'{proxy} | {e}')
        raise e


def get_google_reviews(hex_id, num_reviews):
    # print(f"querying : {hex_id = } ")
    if num_reviews < 11:
        return
    # if num_reviews > 0 and num_reviews % 10 == 0:
    #     num_reviews -= 1
    try:
        data = get_html_response_google(hex_id, num_reviews=num_reviews, proxy=None)
    except:
        return None
    if 'Expecting' in data:
        raise ValueError
    else:
        pass
    data = json.loads(data)
    if data['statusCode'] != 200:
        print(data)
        return 0
    # resp = dict(
    #     date=data['data']['date'], number_of_reviews=data['data']['number_of_reviews'])
    return data['data']


def get_reviews_per_day_(cid, number_of_votes, source):
    if number_of_votes < 30 and source == 'gmaps_v2':
        return {'date': 0, "number_of_reviews": 0}
    f = {'gmaps_v2': get_google_reviews, 'zomato': get_reviews_zomato}
    try:
        res = f[source](cid, number_of_votes)
    except KeyError:
        res = {'date': 0, "number_of_reviews": 0}
    return res





@retry(exceptions=(EmptyPageError,), tries=3, delay=1)
def get_html_response(url, proxy):
    proxy = get_random_proxy()
    # proxy=None
    BASE_DIR = config.PROJECT_DIR / "data" / "zomato"

    dig = hashlib.md5(url.encode()).hexdigest()
    cache_dirs = [BASE_DIR / 'cache', CACHE_DIR, ]
    for cache_dir in cache_dirs:
        cache_dir.mkdir(parents=True, exist_ok=True)
        cache_file = cache_dir / f'{dig}.txt'
        if cache_file.exists():
            with open(cache_file) as f:
                resp = f.read()
                return resp
    # headers = get_headers()
    headers = {"User-Agent": "PostmanRuntime/7.32.3",
               "Accept": "*/*",
               "Cache-Control": "no-cache",
               "Postman-Token": "51227458-1214-44a6-8f4b-f761ec0099ce",
               "Host": "www.zomato.com",
               "Accept-Encoding": "gzip, deflate, br",
               "Connection": "keep-alive",
               "Cookie": r"PHPSESSID=d211e97ee90f64010ad7b769d4d04ecf; ak_bmsc=4B18F182E4143B6397D227D52152B8BB~000000000000000000000000000000~; csrf=21d1af5ae835429f207597a6cec658d6; fbcity=3; fbtrack=eeb9eaaeb90b494e2b326e56643a9bad; fre=0; rd=1380000; zl=en; AWSALBTG=RK0ccuPffBh8VFY/BolIJO3spzo2UtOXUYpj1ruvnVmsCj/pwymk0pgOYRb1U2QtgR2mhV2DYWDmeuqOVVMTRhpSS0+TcPNYh1IElZN9vXVqZ/9G1isrxtMou4ghKKSzdD6Yx8zwzx9Kpjb+Vhe0gDFvXnubSa+oliwYNbKfhlQg; AWSALBTGCORS=RK0ccuPffBh8VFY/BolIJO3spzo2UtOXUYpj1ruvnVmsCj/pwymk0pgOYRb1U2QtgR2mhV2DYWDmeuqOVVMTRhpSS0+TcPNYh1IElZN9vXVqZ/9G1isrxtMou4ghKKSzdD6Yx8zwzx9Kpjb+Vhe0gDFvXnubSa+oliwYNbKfhlQg; locus=%7B%22addressId%22%3A0%2C%22lat%22%3A19.017656%2C%22lng%22%3A72.856178%2C%22cityId%22%3A3%2C%22ltv%22%3A3%2C%22lty%22%3A%22city%22%2C%22fetchFromGoogle%22%3Afalse%2C%22dszId%22%3A77482%2C%22fen%22%3A%22Mumbai%22%7D; ltv=3; lty=3"
               }

    try:
        response = requests.get(
            url,
            headers=headers,
            proxies=proxy, timeout=10,
        )
        if response.status_code == 200:
            with open(cache_file, 'w+') as f:
                f.write(response.text)
            return response.text
        else:
            log.error(response.text, response.status_code)
            raise EmptyPageError
    except Exception as e:
        log.error(f'{proxy} | {e}')
        raise EmptyPageError


def get_reviews_zomato(rest_id, number_of_reviews):
    url = 'https://www.zomato.com/webroutes/reviews/loadMore?res_id={rest_id}&filter=reviews-dd&sort=da'
    url_ = url.format(rest_id=rest_id)
    # print(f"querying : {url_}")
    data = get_html_response(url_, None)
    data = json.loads(data)
    reviews = data['entities']["REVIEWS"]
    timestamps = [reviews[k]['timestamp'] for k in reviews]
    if not timestamps:
        return None
    date = timestamps[0]
    s = data['page_data']['sections']['SECTION_REVIEWS']['pageReviewsText']
    pattern = re.compile("of (?P<number_of_reviews>\d+) reviews")
    try:
        res = pattern.search(s).groupdict()
    except:
        res = {}
    date = datetime.strptime(date, "%b %d, %Y").timestamp()
    res['date'] = int(date)
    return res

# %%
def get_reviews_per_day(df, suffix="_1"):
    for i in range(10):
        dd = df.to_dict(orient='records')
        cids = [i[f'cid_{suffix}'] for i in dd]
        reviews = [i[f'number_of_votes_{suffix}'] for i in dd]
        sources = [i[f'source_{suffix}'] for i in dd]
        with ThreadPoolExecutor(max_workers=10) as executor:
            dd_ = executor.map(get_reviews_per_day_, cids, reviews, sources)
    df['additional_data'] = list(dd_)
    df = pd.concat([df, pd.json_normalize(df['additional_data'])], axis=1).drop(
        columns="additional_data")
    df=df.rename(columns={"date":f"date_{suffix}"})
    df[f'reviews_per_day_{suffix}'] = 86400 * df[f'number_of_votes_{suffix}'] / (df[f'created_at_{suffix}'] - df[f'date_{suffix}'])
    df = df.sort_values(by=f'reviews_per_day_{suffix}', ascending=False)
    return df

# %%
get_reviews_per_day()
# Out:
# 2024-01-31 19:33:40,349 ERROR ZomatoRestaurants:143 - {'https': 'http://vsatyen:unWLWiVPCd@107.181.187.120:10003'} | HTTPSConnectionPool(host='www.zomato.com', port=443): Max retries exceeded with url: /webroutes/reviews/loadMore?res_id=54199&filter=reviews-dd&sort=da (Caused by ProxyError('Unable to connect to proxy', OSError('Tunnel connection failed: 502 Bad Gateway')))
# {'number_of_reviews': '1214', 'date': 1360953000}

# %%
df=pd.read_csv("zomato_gmaps_deduped_data.csv").head(40)

# %%
df
# Out:
#                            id_1      id_2  \
# 0   ChIJR5XRNnc9rjsROCln6pfY2ww  19573302
# 1   ChIJq96HAxUXrjsRTEP8a6kyxeo  19269962
# 2   ChIJnThGvO4XrjsREMVeMmh_GAA  18872888
# 3   ChIJrTLShas9rjsRyvhmFLp2JY0  20024640
# 4   ChIJcyMT4X49rjsRnKUPyPqI12k  18742896
# 5   ChIJrbeWFr49rjsRgrYVepIjUN4     51305
# 6   ChIJAbD-pT09rjsR_XnP7qgnSE4  19449687
# 7   ChIJg3bVF-09rjsRozhTJiYrS8g  18892504
# 8   ChIJbVs8CNA9rjsRLGTel5n5FWk  19487952
# 9   ChIJyUvDu68XrjsREIYDxjUGIag  19016086
# 10  ChIJNTptIjkWrjsRHAmI3yRH5qc     54225
# 11  ChIJJ4HgBaA9rjsRYfBwXHctr4o  18681550
# 12  ChIJdR6R3YU9rjsR0qHeJqZ_IoE  18640097
# 13  ChIJb0fMPSwWrjsRdpbRbGluIT0     50282
# 14  ChIJRxf5LIg9rjsRgw-8-NxBG5U  18554970
# 35          The Higher Taste Stores                483    1688639100
# 36                    Kabab Station                 70    1688639100
# 37                      Sagar Hotel              10700    1688639100
# 38                Third Wave Coffee               1418    1688639100
# 39                       Juice Adda                 21    1688639100
#
#    service_options_1   service_options_2                 brand_id_1  \
# 0                 []          [delivery]                        NaN
# 1                 []  [dining, delivery]                        NaN
# 2                 []  [dining, delivery]                        NaN
# 3                 []  [dining, delivery]                        NaN
# 4                 []  [dining, delivery]                        NaN
# 5                 []  [dining, delivery]                        NaN
# 6                 []  [dining, delivery]              cafecoffeeday
# 7                 []  [dining, delivery]                  chaipoint
# 8                 []  [dining, delivery]                        NaN
# 9                 []  [dining, delivery]                        NaN
# 10                []  [dining, delivery]                        NaN
# 11                []            [dining]                        NaN
# 12                []  [dining, delivery]                   business
# 13                []  [dining, delivery]                        NaN
# 14                []  [dining, delivery]      malgudisdonnebiriyani
# 15                []          [delivery]             cookiemanindia
# 16                []            [dining]                        NaN
# 17                []  [dining, delivery]                        NaN
# 18                []  [dining, delivery]  chickpetdonnebiryanihouse
# 19                []          [delivery]                        NaN
# 20                []          [delivery]                        NaN
# 21                []  [dining, delivery]                        NaN
# 22                []  [dining, delivery]                dhyaanfoods
# 23                []  [dining, delivery]                        NaN
# 24                []  [dining, delivery]              chettyscorner
# 25                []          [delivery]            fivestarchicken
# 26                []  [dining, delivery]            thirdwavecoffee
# 27                []            [dining]                        NaN
# 28                []  [dining, delivery]              ammaspastries
# 29                []          [delivery]              ammaspastries
# 30                []  [dining, delivery]            haagendazsindia
# 31                []  [dining, delivery]                    dominos
# 32                []          [delivery]                      dotpe
# 33                []  [dining, delivery]                        NaN
# 34                []            [dining]                        NaN
# 35                []  [dining, delivery]                highertaste
# 36                []  [dining, delivery]                        NaN
# 37                []  [dining, delivery]                        NaN
# 38                []  [dining, delivery]            thirdwavecoffee
# 39                []            [dining]                        NaN
#
#                          brand_id_2
# 0                               N_A
# 1                     zomato_plan_b
# 2                               N_A
# 3                               N_A
# 4                               N_A
# 5                               N_A
# 6            zomato_cafe_coffee_day
# 7                 zomato_chai_point
# 8                               N_A
# 9                               N_A
# 10              zomato_gullu's_chat
# 11                              N_A
# 12              zomato_green_chilly
# 13    zomato_chung's_chinese_corner
# 14  zomato_malgudi's_donne_biriyani
# 15                zomato_cookie_man
# 16                              N_A
# 17              zomato_kabab_palace
# 18                              N_A
# 19                              N_A
# 20                              N_A
# 21         zomato_new_shanthi_sagar
# 22                              N_A
# 23                              N_A
# 24           zomato_chetty's_corner
# 25         zomato_five_star_chicken
# 26         zomato_third_wave_coffee
# 27                              N_A
# 28           zomato_amma's_pastries
# 29           zomato_amma's_pastries
# 30               zomato_häagen_dazs
# 31            zomato_domino's_pizza
# 32                              N_A
# 33                              N_A
# 34                              N_A
# 35                              N_A
# 36                              N_A
# 37                              N_A
# 38         zomato_third_wave_coffee
# 39                              N_A

# %%
df=get_reviews_per_day(df,"1")
df=get_reviews_per_day(df,"2")

# 22                          Jalpaan  ...  [dining, delivery]
# 1                            Plan B  ...  [dining, delivery]
# 35          The Higher Taste Stores  ...  [dining, delivery]
# 29                  Amma's Pastries  ...          [delivery]
# 17                     Kabab Palace  ...  [dining, delivery]
# 7                        Chai Point  ...  [dining, delivery]
# 33                   Lassi 'n' Mock  ...  [dining, delivery]
# 14         Malgudi's Donne Biriyani  ...  [dining, delivery]
# 2                      Chef Kitchen  ...  [dining, delivery]
# 9                            Kenzai  ...  [dining, delivery]
# 18     Chikpet Donne Biriyani House  ...  [dining, delivery]
# 26                Third Wave Coffee  ...  [dining, delivery]
# 4                1992 Chats - Space  ...  [dining, delivery]
# 24                  Chetty's Corner  ...  [dining, delivery]
# 5                 Kentaky Fast Food  ...  [dining, delivery]
# 19                       Egg Corner  ...          [delivery]
# 6                   Cafe Coffee Day  ...  [dining, delivery]
# 36                    Kabab Station  ...  [dining, delivery]
# 30                      Häagen Dazs  ...  [dining, delivery]
# 8                         Dose Mane  ...  [dining, delivery]
# 15                       Cookie Man  ...          [delivery]
# 32                         Lite-Low  ...          [delivery]
# 27                         Got Cafe  ...            [dining]
# 25                Five Star Chicken  ...          [delivery]
# 20              Royal Cripsy Burger  ...          [delivery]
# 11                   Sannidhi Grand  ...            [dining]
# 3                     Toll Paradise  ...  [dining, delivery]
# 0        H Gowda Biryani Kabab Adda  ...          [delivery]
# 39                       Juice Adda  ...            [dining]
# 34  Karanataka Hindu Military Hotel  ...            [dining]
# 16               Samudra Restaurant  ...            [dining]
#
#                    brand_id_1                       brand_id_2        date_1  \
# 23                        NaN                              N_A  1.467182e+09
# 31                    dominos            zomato_domino's_pizza  1.471520e+09
# 37                        NaN                              N_A  1.563794e+09
# 12                   business              zomato_green_chilly  1.475485e+09
# 13                        NaN    zomato_chung's_chinese_corner  1.329236e+09
# 21                        NaN         zomato_new_shanthi_sagar           NaN
# 10                        NaN              zomato_gullu's_chat  1.314083e+09
# 28              ammaspastries           zomato_amma's_pastries  1.410584e+09
# 38            thirdwavecoffee         zomato_third_wave_coffee  1.535700e+09
# 22                dhyaanfoods                              N_A  1.367998e+09
# 1                         NaN                    zomato_plan_b  1.573829e+09
# 35                highertaste                              N_A  1.449059e+09
# 29              ammaspastries           zomato_amma's_pastries  1.417703e+09
# 17                        NaN              zomato_kabab_palace  1.461062e+09
# 7                   chaipoint                zomato_chai_point  1.584155e+09
# 33                        NaN                              N_A  1.523814e+09
# 14      malgudisdonnebiriyani  zomato_malgudi's_donne_biriyani  1.497459e+09
# 2                         NaN                              N_A  1.538292e+09
# 9                         NaN                              N_A  1.556001e+09
# 18  chickpetdonnebiryanihouse                              N_A  1.580220e+09
# 26            thirdwavecoffee         zomato_third_wave_coffee  1.640233e+09
# 4                         NaN                              N_A  1.531658e+09
# 24              chettyscorner           zomato_chetty's_corner  1.454727e+09
# 5                         NaN                              N_A  1.433700e+09
# 19                        NaN                              N_A  1.640676e+09
# 6               cafecoffeeday           zomato_cafe_coffee_day  1.367641e+09
# 36                        NaN                              N_A  1.544517e+09
# 30            haagendazsindia               zomato_häagen_dazs  1.565869e+09
# 8                         NaN                              N_A  1.596620e+09
# 15             cookiemanindia                zomato_cookie_man  0.000000e+00
# 32                      dotpe                              N_A  0.000000e+00
# 27                        NaN                              N_A  1.649507e+09
# 25            fivestarchicken         zomato_five_star_chicken  1.546441e+09
# 20                        NaN                              N_A  0.000000e+00
# 11                        NaN                              N_A  1.514055e+09
# 3                         NaN                              N_A  0.000000e+00
# 0                         NaN                              N_A  0.000000e+00
# 39                        NaN                              N_A  1.489994e+09
# 34                        NaN                              N_A  1.517585e+09
# 16                        NaN                              N_A  1.558033e+09
#
#     number_of_reviews                                                url  \
# 23               1966  https://www.google.com/maps/preview/review/lis...
# 31               3417  https://www.google.com/maps/preview/review/lis...
# 37              19964  https://www.google.com/maps/preview/review/lis...
# 12               1055  https://www.google.com/maps/preview/review/lis...
# 13               2664  https://www.google.com/maps/preview/review/lis...
# 21               8151  https://www.google.com/maps/preview/review/lis...
# 10               4810  https://www.google.com/maps/preview/review/lis...
# 28               3728  https://www.google.com/maps/preview/review/lis...
# 38               2053  https://www.google.com/maps/preview/review/lis...
# 22               5459  https://www.google.com/maps/preview/review/lis...
# 1                2230  https://www.google.com/maps/preview/review/lis...
# 35                714  https://www.google.com/maps/preview/review/lis...
# 29               1568  https://www.google.com/maps/preview/review/lis...
# 17                805  https://www.google.com/maps/preview/review/lis...
# 7                 194  https://www.google.com/maps/preview/review/lis...
# 33                450  https://www.google.com/maps/preview/review/lis...
# 14               1726  https://www.google.com/maps/preview/review/lis...
# 2                  47  https://www.google.com/maps/preview/review/lis...
# 9                 547  https://www.google.com/maps/preview/review/lis...
# 18                620  https://www.google.com/maps/preview/review/lis...
# 26                740  https://www.google.com/maps/preview/review/lis...
# 4                 155  https://www.google.com/maps/preview/review/lis...
# 24                772  https://www.google.com/maps/preview/review/lis...
# 5                 489  https://www.google.com/maps/preview/review/lis...
# 19                 56  https://www.google.com/maps/preview/review/lis...
# 6                 641  https://www.google.com/maps/preview/review/lis...
# 36                465  https://www.google.com/maps/preview/review/lis...
# 30                 58  https://www.google.com/maps/preview/review/lis...
# 8                 278  https://www.google.com/maps/preview/review/lis...
# 15                  0                                                NaN
# 32                  0                                                NaN
# 27                350  https://www.google.com/maps/preview/review/lis...
# 25                 62  https://www.google.com/maps/preview/review/lis...
# 20                  0                                                NaN
# 11               1106  https://www.google.com/maps/preview/review/lis...
# 3                   0                                                NaN
# 0                   0                                                NaN
# 39                127  https://www.google.com/maps/preview/review/lis...
# 34                164  https://www.google.com/maps/preview/review/lis...
# 16                257  https://www.google.com/maps/preview/review/lis...
#
#     reviews_per_day_1  number_of_reviews      date_2  reviews_per_day_2
# 23           0.727456                113  1607020200          26.252743
# 31           1.282201                 11  1635532200          20.010959
# 37          12.335861                 29  1636655400          17.784036
# 12           0.397440                  6  1576521000           3.965590
# 34  Karanataka Hindu Military Hotel  ...                        NaN
# 16               Samudra Restaurant  ...                        NaN
#
#                          brand_id_2        date_1  number_of_reviews  \
# 23                              N_A  1.467182e+09               1966
# 31            zomato_domino's_pizza  1.471520e+09               3417
# 37                              N_A  1.563794e+09              19964
# 12              zomato_green_chilly  1.475485e+09               1055
# 13    zomato_chung's_chinese_corner  1.329236e+09               2664
# 21         zomato_new_shanthi_sagar           NaN               8151
# 10              zomato_gullu's_chat  1.314083e+09               4810
# 28           zomato_amma's_pastries  1.410584e+09               3728
# 38         zomato_third_wave_coffee  1.535700e+09               2053
# 22                              N_A  1.367998e+09               5459
# 1                     zomato_plan_b  1.573829e+09               2230
# 35                              N_A  1.449059e+09                714
# 29           zomato_amma's_pastries  1.417703e+09               1568
# 17              zomato_kabab_palace  1.461062e+09                805
# 7                 zomato_chai_point  1.584155e+09                194
# 33                              N_A  1.523814e+09                450
# 14  zomato_malgudi's_donne_biriyani  1.497459e+09               1726
# 2                               N_A  1.538292e+09                 47
# 9                               N_A  1.556001e+09                547
# 18                              N_A  1.580220e+09                620
# 26         zomato_third_wave_coffee  1.640233e+09                740
# 4                               N_A  1.531658e+09                155
# 24           zomato_chetty's_corner  1.454727e+09                772
# 5                               N_A  1.433700e+09                489
# 19                              N_A  1.640676e+09                 56
# 6            zomato_cafe_coffee_day  1.367641e+09                641
# 36                              N_A  1.544517e+09                465
# 30               zomato_häagen_dazs  1.565869e+09                 58
# 8                               N_A  1.596620e+09                278
# 15                zomato_cookie_man  0.000000e+00                  0
# 32                              N_A  0.000000e+00                  0
# 27                              N_A  1.649507e+09                350
# 25         zomato_five_star_chicken  1.546441e+09                 62
# 20                              N_A  0.000000e+00                  0
# 11                              N_A  1.514055e+09               1106
# 3                               N_A  0.000000e+00                  0
# 0                               N_A  0.000000e+00                  0
# 39                              N_A  1.489994e+09                127
# 34                              N_A  1.517585e+09                164
# 16                              N_A  1.558033e+09                257
#
#                                                   url reviews_per_day_1  \
# 23  https://www.google.com/maps/preview/review/lis...          0.727456
# 31  https://www.google.com/maps/preview/review/lis...          1.282201
# 37  https://www.google.com/maps/preview/review/lis...         12.335861
# 12  https://www.google.com/maps/preview/review/lis...          0.397440
# 13  https://www.google.com/maps/preview/review/lis...          0.616544
# 21  https://www.google.com/maps/preview/review/lis...               NaN
# 10  https://www.google.com/maps/preview/review/lis...          1.071673
# 28  https://www.google.com/maps/preview/review/lis...          1.154544
# 38  https://www.google.com/maps/preview/review/lis...          1.105078
# 22  https://www.google.com/maps/preview/review/lis...          1.396239
# 1   https://www.google.com/maps/preview/review/lis...          1.479537
# 35  https://www.google.com/maps/preview/review/lis...          0.242762
# 29  https://www.google.com/maps/preview/review/lis...          0.482267
# 17  https://www.google.com/maps/preview/review/lis...          0.287935
# 7   https://www.google.com/maps/preview/review/lis...          0.136941
# 33  https://www.google.com/maps/preview/review/lis...          0.223331
# 14  https://www.google.com/maps/preview/review/lis...          0.718872
# 2   https://www.google.com/maps/preview/review/lis...          0.025172
# 9   https://www.google.com/maps/preview/review/lis...          0.325473
# 18  https://www.google.com/maps/preview/review/lis...          0.432017
# 26  https://www.google.com/maps/preview/review/lis...          1.066975
# 4   https://www.google.com/maps/preview/review/lis...          0.079220
# 24  https://www.google.com/maps/preview/review/lis...          0.271314
# 5   https://www.google.com/maps/preview/review/lis...          0.150436
# 19  https://www.google.com/maps/preview/review/lis...          0.079159
# 6   https://www.google.com/maps/preview/review/lis...          0.164745
# 36  https://www.google.com/maps/preview/review/lis...          0.256250
# 30  https://www.google.com/maps/preview/review/lis...          0.033291
# 8   https://www.google.com/maps/preview/review/lis...          0.224818
# 15                                                NaN          0.000717
# 32                                                NaN          0.000305
# 27  https://www.google.com/maps/preview/review/lis...          0.588171
# 25  https://www.google.com/maps/preview/review/lis...          0.034972
# 20                                                NaN          0.000915
# 11  https://www.google.com/maps/preview/review/lis...          0.502867
# 3                                                 NaN          0.000819
# 0                                                 NaN          0.000051
# 39  https://www.google.com/maps/preview/review/lis...          0.051109
# 34  https://www.google.com/maps/preview/review/lis...          0.073570
# 16  https://www.google.com/maps/preview/review/lis...          0.149510
#
#     number_of_reviews      date_2 reviews_per_day_2      ratio
# 23                113  1607020200         26.252743  12.672458
# 31                 11  1635532200         20.010959   3.633678
# 37                 29  1636655400         17.784036   0.551774
# 12                  6  1576521000          3.965590   4.991271
# 13                234  1493145000          2.493964   2.135074
# 21                 27  1600194600          2.202873   0.279499
# 10                831  1323455400          2.034702   1.798411
# 28                263  1639506600          2.031079   0.311741
# 38                 14  1608575400          1.530222   0.728674
# 22                369  1536777000          1.120806   0.367606
# 1                 785  1574361000          0.955648   0.586815
# 35                 16  1638642600          0.834682   0.686080
# 29                NaN  1598898600          0.731710   0.490639
# 17                314  1437762600          0.700494   2.558491
# 7                 594  1640975400          0.569188   1.715847
# 33                 58  1543602600          0.568905   2.252358
# 14                216  1613759400          0.559618   0.288347
# 2                 981  1319394600          0.431012  39.191489
# 9                 203  1501698600          0.362811   1.451017
# 18                259  1471631400          0.310949   1.308208
# 26                 39  1546713000          0.286121   0.799320
# 4                 263  1434306600          0.220813   4.220779
# 24                 90  1298745000          0.211183   1.239272
# 5                 878  1535740200          0.210775   0.805616
# 19                 27  1633026600          0.136717   1.629630
# 6                1010  1359052200          0.125830   0.758294
# 36                 31  1611253800          0.078154   0.152174
# 30                170  1535308200          0.066491   2.510638
# 8                1533  1476642600          0.055835   0.511194
# 15                618  1518287400          0.035503   5.000000
# 32                 83  1554661800          0.033534   8.666667
# 27                 58  1535308200          0.019159   0.130268
# 25                NaN  1557945000          0.017849   0.435484
# 20                166  1411065000          0.016808   3.000000
# 11                 43  1656181800          0.015972   0.005556
# 3                1645  1446402600          0.014980   2.625000
# 0                3505  1382812200          0.012148  43.000000
# 39                488  1483813800          0.008858   0.169355
# 34                  9  1622399400          0.005217   0.025806
# 16                699  1552674600          0.002542   0.016327
#
# [40 rows x 24 columns]
